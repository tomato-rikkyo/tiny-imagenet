# %%
# Tensorflow 2.3でメモリを指定及び節約して使うためのおまじない。
import tensorflow as tf
physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.set_visible_devices(physical_devices[4], 'GPU')
tf.config.experimental.set_memory_growth(physical_devices[4], True)

import numpy as np
import random

np.random.seed(219)
random.seed(219)
tf.random.set_seed(219)

# %%
import os
dirpath = "/workdir/taki_lab/tiny-imagenet-200/"
train_dir = os.path.join(dirpath, "train")
val_dir = os.path.join(dirpath, "val")
test_dir = os.path.join(dirpath, "test")

# %%
from keras.preprocessing.image import ImageDataGenerator

N_TRAIN = 100000
N_VAL = 10000
INPUT_SIZE = (224, 224)
BATCH_SIZE = 32

train_gen = ImageDataGenerator(rescale=1.0/255,
                              rotation_range=10,
                              width_shift_range=0.1,
                              height_shift_range=0.1,
                              shear_range=0.1,
                              zoom_range=0.1,
                              fill_mode="nearest")

val_gen = ImageDataGenerator(rescale=1.0/255)

train_generator = train_gen.flow_from_directory(train_dir,
                                               target_size=INPUT_SIZE,
                                               batch_size=BATCH_SIZE,
                                               class_mode="categorical")

val_generator = val_gen.flow_from_directory(val_dir,
                                           target_size=INPUT_SIZE,
                                           batch_size=BATCH_SIZE,
                                           class_mode="categorical")
# Out:
# Found 100000 images belonging to 200 classes.
# Found 10000 images belonging to 200 classes.

# %%
from keras import layers, Model

def bottleneck(x, in_ch, out_ch, strides=1):
    params = {
        "kernel_initializer": "he_normal",
        "use_bias": False
    }
    
    inter_ch = out_ch // 4
    h1 = layers.BatchNormalization()(x)
    h1 = layers.ReLU()(h1)
    h1 = layers.Conv2D(inter_ch, kernel_size=1, strides=strides, padding="valid", **params)(h1)
    h1 = layers.BatchNormalization()(h1)
    h1 = layers.ReLU()(h1)
    h1 = layers.Conv2D(inter_ch, kernel_size=3, strides=1, padding="same", **params)(h1)
    h1 = layers.BatchNormalization()(h1)
    h1 = layers.ReLU()(h1)
    h1 = layers.Conv2D(out_ch, kernel_size=1, strides=1, padding="valid", **params)(h1)
    
    if in_ch != out_ch:
        h2 = layers.BatchNormalization()(x)
        h2 = layers.Conv2D(out_ch, kernel_size=1, strides=strides, padding="same", **params)(h2)
    else:
        h2 = x
    
    h = layers.Add()([h1, h2])

    return h

def functional_resnet50(input_shape, output_size):
    inputs = layers.Input(input_shape)
    x = layers.BatchNormalization()(inputs)
    x = layers.ReLU()(x)
    x = layers.Conv2D(64, 7, 2, padding="same", kernel_initializer="he_normal", use_bias=False)(x)
    x = layers.MaxPool2D(3, 2, padding="same")(x)
    
    x = bottleneck(x, 64, 256)
    x = bottleneck(x, 256, 256)
    x = bottleneck(x, 256, 256)
    
    x = layers.Conv2D(512, kernel_size=1, strides=2)(x)
    x = bottleneck(x, 512, 512)
    x = bottleneck(x, 512, 512)
    x = bottleneck(x, 512, 512)
    x = bottleneck(x, 512, 512)
    
    x = layers.Conv2D(1024, kernel_size=1, strides=2, use_bias=False)(x)
    x = bottleneck(x, 1024, 1024)
    x = bottleneck(x, 1024, 1024)
    x = bottleneck(x, 1024, 1024)
    x = bottleneck(x, 1024, 1024)
    x = bottleneck(x, 1024, 1024)
    x = bottleneck(x, 1024, 1024)
    
    x = layers.Conv2D(2048, kernel_size=1, strides=2, use_bias=False)(x)
    x = bottleneck(x,2048, 2048)
    x = bottleneck(x,2048, 2048)
    x = bottleneck(x,2048, 2048)
    
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(1024, activation="relu")(x)
    outputs = layers.Dense(output_size, activation="softmax", kernel_initializer="he_normal")(x)
    return Model(inputs=inputs, outputs=outputs)

# %%
from keras import optimizers
import wandb
from wandb.keras import WandbCallback
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# wandbの設定
wandb.init(project="tiny-image-net", name="resnet50_pre-act_lr")
config = wandb.config
config.learning_rate = 0.0001
config.lr_factor = 0.5
config.optimaizer = "Adam"
config.batch_size = BATCH_SIZE
config.input_size = INPUT_SIZE
config.rotation_range = 10
config.width_shift_range = 0.1
config.height_shift_range = 0.1
config.shear_range = 0.1
config.zoom_range = 0.1

# 最適化設定
model = functional_resnet50((224, 224, 3), 200)
model.compile(optimizer=optimizers.Adam(learning_rate=1e-4),
             loss="categorical_crossentropy",
             metrics=["acc"])

early_stopping = EarlyStopping(monitor="val_acc", patience=5)
reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=2, min_lr=1e-5)

callback_list = [early_stopping, reduce_lr, WandbCallback()]


# 学習
history = model.fit(train_generator,
    steps_per_epoch=N_TRAIN//BATCH_SIZE,
    epochs=1000,
    validation_data=val_generator,
    validation_steps=N_VAL//BATCH_SIZE,
    use_multiprocessing=True,
    workers=24,
    callbacks=callback_list)
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/tomato-ai/tiny-image-net" target="_blank">https://app.wandb.ai/tomato-ai/tiny-image-net</a><br/>
#                 Run page: <a href="https://app.wandb.ai/tomato-ai/tiny-image-net/runs/1eg67ydl" target="_blank">https://app.wandb.ai/tomato-ai/tiny-image-net/runs/1eg67ydl</a><br/>
# wandb: Wandb version 0.10.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# Epoch 1/1000
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3124/3125 [============================>.] - ETA: 0s - loss: 4.8146 - acc: 0.0521WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - ETA: 0s - loss: 4.8145 - acc: 0.0521WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - 644s 206ms/step - loss: 4.8145 - acc: 0.0521 - val_loss: 5.6470 - val_acc: 0.0417
# Epoch 2/1000
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3124/3125 [============================>.] - ETA: 0s - loss: 4.1229 - acc: 0.1228WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - ETA: 0s - loss: 4.1227 - acc: 0.1228WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - 640s 205ms/step - loss: 4.1227 - acc: 0.1228 - val_loss: 4.1008 - val_acc: 0.1311
# Epoch 3/1000
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3124/3125 [============================>.] - ETA: 0s - loss: 3.7160 - acc: 0.1810WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - ETA: 0s - loss: 3.7161 - acc: 0.1810WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - 648s 207ms/step - loss: 3.7161 - acc: 0.1810 - val_loss: 3.7034 - val_acc: 0.1920
# Epoch 4/1000
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3124/3125 [============================>.] - ETA: 0s - loss: 3.4143 - acc: 0.2288WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - ETA: 0s - loss: 3.4142 - acc: 0.2288WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - 641s 205ms/step - loss: 3.4142 - acc: 0.2288 - val_loss: 3.4510 - val_acc: 0.2318
# Epoch 5/1000
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3124/3125 [============================>.] - ETA: 0s - loss: 3.1555 - acc: 0.2740WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - ETA: 0s - loss: 3.1555 - acc: 0.2740WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - 637s 204ms/step - loss: 3.1555 - acc: 0.2740 - val_loss: 3.4949 - val_acc: 0.2445
# Epoch 6/1000
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3124/3125 [============================>.] - ETA: 0s - loss: 2.9381 - acc: 0.3125WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - ETA: 0s - loss: 2.9380 - acc: 0.3125WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - 639s 204ms/step - loss: 2.9380 - acc: 0.3125 - val_loss: 3.0996 - val_acc: 0.2925
# Epoch 7/1000
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3124/3125 [============================>.] - ETA: 0s - loss: 2.7424 - acc: 0.3521WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - ETA: 0s - loss: 2.7426 - acc: 0.3521WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - 640s 205ms/step - loss: 2.7426 - acc: 0.3521 - val_loss: 2.9259 - val_acc: 0.3290
# Epoch 8/1000
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3124/3125 [============================>.] - ETA: 0s - loss: 2.5775 - acc: 0.3838WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - ETA: 0s - loss: 2.5775 - acc: 0.3838WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - 638s 204ms/step - loss: 2.5775 - acc: 0.3838 - val_loss: 2.8957 - val_acc: 0.3328
# Epoch 9/1000
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3124/3125 [============================>.] - ETA: 0s - loss: 2.4225 - acc: 0.4137WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - ETA: 0s - loss: 2.4225 - acc: 0.4137WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - 640s 205ms/step - loss: 2.4225 - acc: 0.4137 - val_loss: 2.6563 - val_acc: 0.3894
# Epoch 10/1000
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3124/3125 [============================>.] - ETA: 0s - loss: 2.2895 - acc: 0.4391WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - ETA: 0s - loss: 2.2896 - acc: 0.4390WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - 638s 204ms/step - loss: 2.2896 - acc: 0.4390 - val_loss: 2.6192 - val_acc: 0.3997
# Epoch 11/1000
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3124/3125 [============================>.] - ETA: 0s - loss: 2.1700 - acc: 0.4648WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - ETA: 0s - loss: 2.1700 - acc: 0.4648WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - 638s 204ms/step - loss: 2.1700 - acc: 0.4648 - val_loss: 2.5241 - val_acc: 0.4221
# Epoch 12/1000
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3124/3125 [============================>.] - ETA: 0s - loss: 2.0569 - acc: 0.4862WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - ETA: 0s - loss: 2.0567 - acc: 0.4862WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - 636s 203ms/step - loss: 2.0567 - acc: 0.4862 - val_loss: 2.6335 - val_acc: 0.4037
# Epoch 13/1000
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3124/3125 [============================>.] - ETA: 0s - loss: 1.9576 - acc: 0.5084WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - ETA: 0s - loss: 1.9577 - acc: 0.5084WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - 636s 204ms/step - loss: 1.9577 - acc: 0.5084 - val_loss: 2.4641 - val_acc: 0.4300
# Epoch 14/1000
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3124/3125 [============================>.] - ETA: 0s - loss: 1.8645 - acc: 0.5278WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - ETA: 0s - loss: 1.8644 - acc: 0.5278WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - 639s 204ms/step - loss: 1.8644 - acc: 0.5278 - val_loss: 2.4647 - val_acc: 0.4333
# Epoch 15/1000
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3124/3125 [============================>.] - ETA: 0s - loss: 1.7747 - acc: 0.5454WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - ETA: 0s - loss: 1.7748 - acc: 0.5454WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - 640s 205ms/step - loss: 1.7748 - acc: 0.5454 - val_loss: 2.5847 - val_acc: 0.4325
# Epoch 16/1000
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3124/3125 [============================>.] - ETA: 0s - loss: 1.4446 - acc: 0.6218WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - ETA: 0s - loss: 1.4445 - acc: 0.6218WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - 641s 205ms/step - loss: 1.4445 - acc: 0.6218 - val_loss: 2.2456 - val_acc: 0.4896
# Epoch 17/1000
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3124/3125 [============================>.] - ETA: 0s - loss: 1.3397 - acc: 0.6444WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - ETA: 0s - loss: 1.3398 - acc: 0.6444WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - 640s 205ms/step - loss: 1.3398 - acc: 0.6444 - val_loss: 2.2711 - val_acc: 0.4924
# Epoch 18/1000
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3124/3125 [============================>.] - ETA: 0s - loss: 1.2598 - acc: 0.6643WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - ETA: 0s - loss: 1.2599 - acc: 0.6643WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - 633s 202ms/step - loss: 1.2599 - acc: 0.6643 - val_loss: 2.2958 - val_acc: 0.4943
# Epoch 19/1000
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3124/3125 [============================>.] - ETA: 0s - loss: 1.0600 - acc: 0.7130WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - ETA: 0s - loss: 1.0600 - acc: 0.7129WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - 641s 205ms/step - loss: 1.0600 - acc: 0.7129 - val_loss: 2.1420 - val_acc: 0.5226
# Epoch 20/1000
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3124/3125 [============================>.] - ETA: 0s - loss: 0.9973 - acc: 0.7268WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - ETA: 0s - loss: 0.9974 - acc: 0.7268WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - 637s 204ms/step - loss: 0.9974 - acc: 0.7268 - val_loss: 2.1578 - val_acc: 0.5293
# Epoch 21/1000
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3124/3125 [============================>.] - ETA: 0s - loss: 0.9427 - acc: 0.7412WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - ETA: 0s - loss: 0.9428 - acc: 0.7412WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - 637s 204ms/step - loss: 0.9428 - acc: 0.7412 - val_loss: 2.2439 - val_acc: 0.5213
# Epoch 22/1000
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3124/3125 [============================>.] - ETA: 0s - loss: 0.8347 - acc: 0.7700WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - ETA: 0s - loss: 0.8348 - acc: 0.7700WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - 638s 204ms/step - loss: 0.8348 - acc: 0.7700 - val_loss: 2.1523 - val_acc: 0.5386
# Epoch 23/1000
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3124/3125 [============================>.] - ETA: 0s - loss: 0.7975 - acc: 0.7805WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - ETA: 0s - loss: 0.7975 - acc: 0.7805WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - 633s 203ms/step - loss: 0.7975 - acc: 0.7805 - val_loss: 2.1869 - val_acc: 0.5367
# Epoch 24/1000
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3124/3125 [============================>.] - ETA: 0s - loss: 0.7571 - acc: 0.7911WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - ETA: 0s - loss: 0.7572 - acc: 0.7911WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 3125/3125 [==============================] - 636s 204ms/step - loss: 0.7572 - acc: 0.7911 - val_loss: 2.1846 - val_acc: 0.5400
# Epoch 25/1000
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#  493/3125 [===>..........................] - ETA: 8:32 - loss: 0.7304 - acc: 0.7997
